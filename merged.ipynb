# %%
# Import dependencies
import pandas as pd

# %%
# Raw data file
file = "2018/JC-201801-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df = pd.read_csv(file)
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
# Raw data file
file = "2018/JC-201802-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df2 = pd.read_csv(file)
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
# Raw data file
file = "2018/JC-201803-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df3 = pd.read_csv(file)
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3202     Newport PATH
# ...

# %%
# Raw data file
file = "2018/JC-201804-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df4 = pd.read_csv(file)
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1           298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2          1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3          1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4           559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3638       Washington St
# ...

# %%
# Raw data file
file = "2018/JC-201805-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df5 = pd.read_csv(file)
df5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           131  2018-05-01 07:29:57.5490  2018-05-01 07:32:08.6160
# 1            73  2018-05-01 08:13:58.2560  2018-05-01 08:15:11.9230
# 2          4929  2018-05-01 08:17:21.3110  2018-05-01 09:39:31.0770
# 3           432  2018-05-01 08:25:58.7150  2018-05-01 08:33:10.8960
# 4           432  2018-05-01 08:28:09.9160  2018-05-01 08:35:22.1440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
# Raw data file
file = "2018/JC-201806-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df6 = pd.read_csv(file)
df6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
# Raw data file
file = "2018/JC-201807-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df7 = pd.read_csv(file)
df7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
# Raw data file
file = "2018/JC-201808-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df8 = pd.read_csv(file)
df8.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
# Raw data file
file = "2018/JC-201809-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df9 = pd.read_csv(file)
df9.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3267        Morris Canal
# ...

# %%
# Raw data file
file = "2018/JC-201810-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df10 = pd.read_csv(file)
df10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1           122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2           211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3           342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4          2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3639        Harborside
# ...

# %%
merged_df = pd.concat([df, df2, df3, df4, df5, df6, df7, df8, df9, df10])
merged_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
merged_df.set_index('tripduration', inplace=True)

# %%
merged_df.head()
# Out:
#                              starttime                  stoptime  \
# tripduration
# 932           2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 550           2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 510           2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 354           2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 250           2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#               start station id start station name  start station latitude  \
# tripduration
# 932                       3183     Exchange Place               40.716247
# 550                       3183     Exchange Place               40.716247
# 510                       3183     Exchange Place               40.716247
# 354                       3183     Exchange Place               40.716247
# 250                       3183     Exchange Place               40.716247
#
#               start station longitude  end station id end station name  \
# tripduration
# ...

# %%
merged_df.to_csv('JC-2018.csv')

# %%
 # Raw data file
file = "2018/201801-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df11 = pd.read_csv(file)
df11.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
 # Raw data file
file = "2018/201802-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df12 = pd.read_csv(file)
df12.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           771  2018-02-01 00:14:16.4120  2018-02-01 00:27:08.2290
# 1           264  2018-02-01 05:14:45.1790  2018-02-01 05:19:09.6860
# 2           819  2018-02-01 06:48:55.2290  2018-02-01 07:02:35.0290
# 3           646  2018-02-01 07:12:50.1740  2018-02-01 07:23:36.5280
# 4          1312  2018-02-01 07:46:48.8750  2018-02-01 08:08:41.5430
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929             379                W 31 St & 7 Ave
# ...

# %%
 # Raw data file
file = "2018/201803-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df13 = pd.read_csv(file)
df13.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           816  2018-03-01 02:29:13.7270  2018-03-01 02:42:50.1460
# 1           235  2018-03-01 05:12:37.0320  2018-03-01 05:16:32.1010
# 2          1250  2018-03-01 05:45:49.9000  2018-03-01 06:06:39.9080
# 3           741  2018-03-01 06:54:19.6150  2018-03-01 07:06:40.9790
# 4           727  2018-03-01 07:08:38.8610  2018-03-01 07:20:46.8500
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929             379                W 31 St & 7 Ave
# ...

# %%
 # Raw data file
file = "2018/201804-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df14 = pd.read_csv(file)
df14.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           840  2018-04-01 03:07:39.0700  2018-04-01 03:21:39.1280
# 1          1438  2018-04-01 07:20:02.2150  2018-04-01 07:44:00.5690
# 2           219  2018-04-01 08:11:14.4060  2018-04-01 08:14:53.7880
# 3           410  2018-04-01 08:52:32.3730  2018-04-01 08:59:23.2190
# 4           485  2018-04-01 09:37:34.3270  2018-04-01 09:45:39.9980
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id       end station name  \
# 0               -73.993929             379        W 31 St & 7 Ave
# ...

# %%
 # Raw data file
file = "2018/201805-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df15 = pd.read_csv(file)
df15.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           367  2018-05-01 05:06:16.5840  2018-05-01 05:12:23.9650
# 1          1313  2018-05-01 06:25:49.4250  2018-05-01 06:47:42.7120
# 2          1798  2018-05-01 06:40:26.4450  2018-05-01 07:10:25.1790
# 3           518  2018-05-01 07:06:02.9730  2018-05-01 07:14:41.0040
# 4           109  2018-05-01 07:26:32.3450  2018-05-01 07:28:21.5420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             514         12 Ave & W 40 St
# ...

# %%
 # Raw data file
file = "2018/201806-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df16 = pd.read_csv(file)
df16.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1           480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2           692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3           664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4           818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  \
# 0               -73.993929             173  Broadway & W 49 St
# ...

# %%
 # Raw data file
file = "2018/201807-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df17 = pd.read_csv(file)
df17.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           500  2018-07-01 00:33:51.2640  2018-07-01 00:42:12.0280
# 1           455  2018-07-01 02:06:54.0270  2018-07-01 02:14:29.0900
# 2          1080  2018-07-01 02:09:16.4640  2018-07-01 02:27:17.0290
# 3           632  2018-07-01 02:55:04.5870  2018-07-01 03:05:36.7910
# 4          1676  2018-07-01 03:24:27.4350  2018-07-01 03:52:23.7760
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  \
# 0               -73.993929            3236  W 42 St & Dyer Ave
# ...

# %%
 # Raw data file
file = "2018/201808-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df18 = pd.read_csv(file)
df18.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           681  2018-08-01 00:00:07.3210  2018-08-01 00:11:28.9920
# 1           625  2018-08-01 00:00:19.7480  2018-08-01 00:10:45.0290
# 2          1319  2018-08-01 00:00:21.1750  2018-08-01 00:22:20.6370
# 3           220  2018-08-01 00:00:26.4700  2018-08-01 00:04:06.8190
# 4           398  2018-08-01 00:00:30.2910  2018-08-01 00:07:09.2810
#
#    start station id       start station name  start station latitude  \
# 0            3162.0       W 78 St & Broadway               40.783400
# 1            3260.0  Mercer St & Bleecker St               40.727064
# 2             403.0           E 2 St & 2 Ave               40.725029
# 3            3637.0  Fulton St & Waverly Ave               40.683239
# 4            3662.0     31 Ave & Steinway St               40.761294
#
#    start station longitude  end station id             end station name  \
# ...

# %%
 # Raw data file
file = "2018/201809-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df19 = pd.read_csv(file)
df19.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1           132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2          3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3           436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4          8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# ...

# %%
 # Raw data file
file = "2018/201810-citibike-tripdata.csv"

# Read purchasing file and store into pandas data frame
df20 = pd.read_csv(file)
df20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           330  2018-10-01 00:00:00.7010  2018-10-01 00:05:30.8490
# 1           309  2018-10-01 00:00:13.5780  2018-10-01 00:05:23.2310
# 2           734  2018-10-01 00:00:16.6040  2018-10-01 00:12:31.5050
# 3           788  2018-10-01 00:00:35.0670  2018-10-01 00:13:43.5780
# 4          1136  2018-10-01 00:00:38.1410  2018-10-01 00:19:34.6490
#
#    start station id        start station name  start station latitude  \
# 0             293.0     Lafayette St & E 8 St               40.730207
# 1             433.0  old - E 13 St & Avenue A               40.729554
# 2            3472.0          W 15 St & 10 Ave               40.742754
# 3             417.0    Barclay St & Church St               40.712912
# 4            3699.0           W 50 St & 9 Ave               40.763605
#
#    start station longitude  end station id    end station name  \
# 0               -73.991026           504.0     1 Ave & E 16 St
# ...

# %%
merged_df2 = pd.concat([df11, df12, df13, df14, df15, df16, df17, df18, df19, df20])
merged_df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
merged_df2.set_index('tripduration', inplace=True)
merged_df2.head()
# Out:
#                              starttime                  stoptime  \
# tripduration
# 970           2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 723           2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 496           2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 306           2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 306           2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#               start station id start station name  start station latitude  \
# tripduration
# 970                       72.0   W 52 St & 11 Ave               40.767272
# 723                       72.0   W 52 St & 11 Ave               40.767272
# 496                       72.0   W 52 St & 11 Ave               40.767272
# 306                       72.0   W 52 St & 11 Ave               40.767272
# 306                       72.0   W 52 St & 11 Ave               40.767272
#
#               start station longitude  end station id  \
# tripduration
# ...

# %%
merged_df2.to_csv('NYC-2018.csv')
